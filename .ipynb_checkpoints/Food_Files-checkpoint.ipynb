# %%
import json

f = open('foods.txt', 'r')
foodsList = f.readlines()
f.close()

print("FOODS")
for line in foodsList:
    print(line)

h = open('highfiber.txt', 'r')
highfiberList = h.readlines()
h.close()

print("HIGH FIBER")
for line in highfiberList:
    print(line)

l = open('lowfat.txt', 'r')
lowfatList = l.readlines()
l.close()

print("LOW FAT")
for line in lowfatList:
    print(line)

lg = open('low-glycemic-index.txt', 'r')
lowGlycemicIndexList = lg.readlines()
lg.close()

print("LOW GLYCEMIC INDEX")
for line in lowGlycemicIndexList:
    print(line)

del foodsList[12]
del highfiberList[12]
del lowfatList[12]
del lowGlycemicIndexList[12]

del foodsList[24]
del highfiberList[24]
del lowfatList[24]
del lowGlycemicIndexList[24]

del foodsList[28]
del highfiberList[28]
del lowfatList[28]
del lowGlycemicIndexList[28]

foodsList[6] = 'blueberry muffin'
foodsList[14] = 'salmon'

highfiberList[4] = 'no'
highfiberList[20] = 'yes'
highfiberList[29] = 'no'

lowfatList[1] = 'no'
lowfatList[2] = 'yes'
lowfatList[8] = 'yes'
lowfatList[29] = 'yes'

lowGlycemicIndexList[6] = 'no'
lowGlycemicIndexList[28] = 'no'

highfiberListStripped = []
for newline in highfiberList:
    highfiberListStripped.append(newline.rstrip())
    
foodsListStripped = []
for newline in foodsList:
    foodsListStripped.append(newline.rstrip())
    
lowfatListStripped = []
for newline in lowfatList:
    lowfatListStripped.append(newline.rstrip())
    
lowGlycemicIndexListStripped = []
for newline in lowGlycemicIndexList:
    lowGlycemicIndexListStripped.append(newline.rstrip())
    
foodsDict = {}
highfiberDict = {}
lowfatDict = {}
lowGlycemicIndexDict = {}

for keyvalue in foodsDict:
    


# json.dumps(foodsList)
# Out:
# FOODS
# foods
#
# Donut
#
# Carrot
#
# Strawberry
#
# Doritos: Cool Ranch
#
# Pasta
#
# Blue Berry Muffin
#
# Strawberry Smoothie
#
# Chocolate Milk
#
# Protein Bar
#
# Orange Juice
#
# Greek Salad
#
#
#
# Takis
#
# Popcorn
#
# salmon2
#
# pizza rolls
#
# canteloupe
#
# potatoes
#
# watermelon
#
# oatmeal
#
# Slim Jims
#
# Brussel Sprouts
#
# Lasagna
#
# Fried Chicken
#
# Pizza Rolls
#
# Bacon
#
# French Fries
#
# Skim Milk
#
# Green Beans
#
# ja&ng
#
# Doritos: Nacho Cheese
#
# Hot Sauce
#
# Sriacha
#
# HIGH FIBER
# high fiber
#
# no
#
# yes
#
# yes
#
# nO
#
# no
#
# no
#
# no
#
# no
#
# yes
#
# no
#
# no
#
#
#
# no
#
# yes
#
# yes
#
# no
#
# yes
#
# no
#
# yes
#
# yes
#
# yEs
#
# yes
#
# no
#
# no
#
# no
#
# no
#
# no
#
# no
#
# yes
#
# 23314
#
# no
#
# No
#
# yes
#
# LOW FAT
# low fat
#
# No
#
# Yes
#
# yes
#
# no
#
# no
#
# no
#
# no
#
# No
#
# yes
#
# no
#
# no
#
#
#
# no
#
# no
#
# yes
#
# no
#
# yes
#
# yes
#
# yes
#
# yes
#
# no
#
# yes
#
# no
#
# no
#
# no
#
# no
#
# no
#
# ...

# %%
lowGlycemicIndexListStripped
# Out:
# ['low glycemic index',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes']
